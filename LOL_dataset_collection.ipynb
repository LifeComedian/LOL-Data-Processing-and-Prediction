# %%
from __future__ import annotations

import json
import os
from pathlib import Path

CONFIG = {
    "riot_api_key": os.getenv("RIOT_API_KEY", "RGAPI-fb1828da-c76f-41f2-ad12-17b0bf4db4d6"),
    "region_routing": os.getenv("RIOT_REGION_ROUTING", "asia"),
    "platform_routing": os.getenv("RIOT_PLATFORM_ROUTING", "kr"),
    "queue_id": int(os.getenv("RIOT_QUEUE_FILTER", "420") or 420),
    "target_match_count": 10000,
    "seeds_path": Path("seeds.txt"),
    "raw_output_path": Path("raw.csv"),
    "timeline_dir": Path("timeline"),
    "match_ids_per_page": 100,
    "max_player_queue": 400,
    "request_window_seconds": 120.0,
    "request_window_limit": 95,
    "sleep_between_matches": 0.0,
}

if not CONFIG["riot_api_key"]:
    raise RuntimeError("Set the RIOT_API_KEY environment variable before running this notebook.")

CONFIG
# Out:
# {'riot_api_key': 'RGAPI-fb1828da-c76f-41f2-ad12-17b0bf4db4d6',
#  'region_routing': 'asia',
#  'platform_routing': 'kr',
#  'queue_id': 420,
#  'target_match_count': 10000,
#  'seeds_path': WindowsPath('seeds.txt'),
#  'raw_output_path': WindowsPath('raw.csv'),
#  'timeline_dir': WindowsPath('timeline'),
#  'match_ids_per_page': 100,
#  'max_player_queue': 400,
#  'request_window_seconds': 120.0,
#  'request_window_limit': 95,
#  'sleep_between_matches': 0.0}

# %%
import csv
import os
import time
from collections import deque
from typing import Any, Dict, List, Optional, Sequence, Set, Tuple
from urllib.parse import quote

import pandas as pd
import requests

API_KEY = CONFIG["riot_api_key"]
REGION_ROUTING = CONFIG["region_routing"]
QUEUE_FILTER = CONFIG.get("queue_id")
MATCH_IDS_PER_PAGE = min(CONFIG["match_ids_per_page"], 100)
MAX_PLAYER_QUEUE = CONFIG["max_player_queue"]
REQUEST_RETRIES = 5
REQUEST_WINDOW_SECONDS = CONFIG["request_window_seconds"]
REQUEST_WINDOW_LIMIT = CONFIG["request_window_limit"]
SLEEP_BETWEEN_MATCHES = CONFIG["sleep_between_matches"]

if isinstance(QUEUE_FILTER, str) and not QUEUE_FILTER:
    QUEUE_FILTER = None

HEADERS = {"X-Riot-Token": API_KEY} if API_KEY else {}
REQUEST_TIMES: deque[float] = deque()

FIELDNAMES = [
    "match_id",
    "data_version",
    "queue_id",
    "map_id",
    "game_mode",
    "game_type",
    "game_version",
    "game_creation",
    "game_start_timestamp",
    "game_end_timestamp",
    "game_duration",
    "tournament_code",
    "participant_puuid",
    "participant_riotIdGameName",
    "participant_riotIdTagline",
    "participant_summonerId",
    "participant_summonerName",
    "profile_icon",
    "team_id",
    "team_side",
    "team_position",
    "individual_position",
    "role",
    "lane",
    "win",
    "champion_id",
    "champion_name",
    "champ_level",
    "kills",
    "deaths",
    "assists",
    "kda",
    "gold_earned",
    "gold_spent",
    "total_damage_dealt",
    "total_damage_dealt_to_champions",
    "total_damage_taken",
    "damage_dealt_to_objectives",
    "damage_dealt_to_turrets",
    "total_heal",
    "total_heals_on_teammates",
    "total_damage_shielded_on_teammates",
    "vision_score",
    "wards_placed",
    "wards_killed",
    "vision_wards_bought",
    "total_minions_killed",
    "neutral_minions_killed",
    "cs",
    "double_kills",
    "triple_kills",
    "quadra_kills",
    "penta_kills",
    "summoner1_id",
    "summoner2_id",
    "item0",
    "item1",
    "item2",
    "item3",
    "item4",
    "item5",
    "item6",
    "time_played",
    "time_ccing_others",
    "total_time_cc_dealt",
]

def log(message: str) -> None:
    now = time.strftime("%H:%M:%S")
    print(f"[{now}] {message}")

def throttle() -> None:
    if REQUEST_WINDOW_LIMIT <= 0:
        return
    now = time.time()
    while REQUEST_TIMES and now - REQUEST_TIMES[0] >= REQUEST_WINDOW_SECONDS:
        REQUEST_TIMES.popleft()
    if len(REQUEST_TIMES) >= REQUEST_WINDOW_LIMIT:
        wait = REQUEST_WINDOW_SECONDS - (now - REQUEST_TIMES[0]) + 0.05
        if wait > 0:
            time.sleep(wait)

def riot_get(url: str, params: Optional[Dict[str, Any]] = None) -> Optional[Any]:
    if not API_KEY:
        raise RuntimeError("Set RIOT_API_KEY in your environment before running this notebook.")
    for attempt in range(REQUEST_RETRIES):
        throttle()
        try:
            resp = requests.get(url, headers=HEADERS, params=params, timeout=20)
        except requests.RequestException as exc:
            REQUEST_TIMES.append(time.time())
            log(f"Request error ({exc}). Retrying...")
            time.sleep(1 + attempt)
            continue
        REQUEST_TIMES.append(time.time())
        if resp.status_code == 200:
            if resp.content:
                return resp.json()
            return None
        if resp.status_code == 429:
            retry_after = float(resp.headers.get("Retry-After", "1"))
            log(f"Rate limited. Sleeping for {retry_after} seconds.")
            time.sleep(retry_after + 0.1)
            continue
        if resp.status_code == 404:
            return None
        if resp.status_code >= 500:
            time.sleep(1 + attempt)
            continue
        log(f"HTTP {resp.status_code} error: {resp.text}")
        return None
    log(f"Gave up on {url} after {REQUEST_RETRIES} attempts.")
    return None

def read_seeds(path: str) -> List[str]:
    if not os.path.exists(path):
        log(f"Seeds file not found at {path}.")
        return []
    seeds: List[str] = []
    with open(path, "r", encoding="utf-8") as handle:
        for line in handle:
            value = line.strip()
            if not value or value.startswith("//"):
                continue
            seeds.append(value)
    return seeds

def looks_like_puuid(seed: str) -> bool:
    return len(seed) >= 40 and all(ch.isalnum() or ch in "-_=" for ch in seed)

def resolve_seed(seed: str) -> Optional[Tuple[str, str]]:
    if looks_like_puuid(seed):
        return seed, seed
    if "#" in seed:
        game_name, tag_line = seed.split("#", 1)
        url = (
            f"https://{REGION_ROUTING}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/"
            f"{quote(game_name)}/{quote(tag_line)}"
        )
        data = riot_get(url)
        if data and isinstance(data, dict) and data.get("puuid"):
            display = f"{data.get('gameName', game_name)}#{data.get('tagLine', tag_line)}"
            return data["puuid"], display
    log(f"Could not resolve seed '{seed}'. Use Riot ID (Name#Tag) or a PUUID.")
    return None

def fetch_match_ids(puuid: str, start: int) -> List[str]:
    params: Dict[str, Any] = {"start": start, "count": MATCH_IDS_PER_PAGE}
    if QUEUE_FILTER is not None:
        params["queue"] = QUEUE_FILTER
    url = f"https://{REGION_ROUTING}.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids"
    data = riot_get(url, params=params)
    if isinstance(data, list):
        return data
    return []

def fetch_match(match_id: str) -> Optional[Dict[str, Any]]:
    url = f"https://{REGION_ROUTING}.api.riotgames.com/lol/match/v5/matches/{match_id}"
    data = riot_get(url)
    if isinstance(data, dict):
        return data
    return None

def team_side(team_id: Optional[int]) -> str:
    if team_id == 100:
        return "blue"
    if team_id == 200:
        return "red"
    return ""

def extract_rows(match: Dict[str, Any]) -> Tuple[List[Dict[str, Any]], Set[str]]:
    metadata = match.get("metadata") or {}
    info = match.get("info") or {}
    if QUEUE_FILTER is not None and info.get("queueId") != QUEUE_FILTER:
        return [], set()
    match_id = metadata.get("matchId") or info.get("gameId") or ""
    game_duration = info.get("gameDuration")
    if isinstance(game_duration, dict):
        game_duration = game_duration.get("duration")
    base = {
        "match_id": match_id,
        "data_version": metadata.get("dataVersion", ""),
        "queue_id": info.get("queueId"),
        "map_id": info.get("mapId"),
        "game_mode": info.get("gameMode", ""),
        "game_type": info.get("gameType", ""),
        "game_version": info.get("gameVersion", ""),
        "game_creation": info.get("gameCreation"),
        "game_start_timestamp": info.get("gameStartTimestamp"),
        "game_end_timestamp": info.get("gameEndTimestamp"),
        "game_duration": game_duration,
        "tournament_code": info.get("tournamentCode", ""),
    }
    participants = info.get("participants") or []
    rows: List[Dict[str, Any]] = []
    puuids: Set[str] = set()
    for participant in participants:
        puuid = participant.get("puuid", "")
        puuids.add(puuid)
        kills = participant.get("kills", 0) or 0
        deaths = participant.get("deaths", 0) or 0
        assists = participant.get("assists", 0) or 0
        total_minions = participant.get("totalMinionsKilled")
        neutral_minions = participant.get("neutralMinionsKilled")
        row = dict(base)
        row["participant_puuid"] = puuid
        row["participant_riotIdGameName"] = participant.get("riotIdGameName", "")
        row["participant_riotIdTagline"] = participant.get("riotIdTagline", "")
        row["participant_summonerId"] = participant.get("summonerId", "")
        row["participant_summonerName"] = participant.get("summonerName", "")
        row["profile_icon"] = participant.get("profileIcon")
        team_id = participant.get("teamId")
        row["team_id"] = team_id
        row["team_side"] = team_side(team_id)
        row["team_position"] = participant.get("teamPosition", "")
        row["individual_position"] = participant.get("individualPosition", "")
        row["role"] = participant.get("role", "")
        row["lane"] = participant.get("lane", "")
        row["win"] = participant.get("win")
        row["champion_id"] = participant.get("championId")
        row["champion_name"] = participant.get("championName", "")
        row["champ_level"] = participant.get("champLevel")
        row["kills"] = kills
        row["deaths"] = deaths
        row["assists"] = assists
        row["kda"] = round((kills + assists) / max(1, deaths), 3)
        row["gold_earned"] = participant.get("goldEarned")
        row["gold_spent"] = participant.get("goldSpent")
        row["total_damage_dealt"] = participant.get("totalDamageDealt")
        row["total_damage_dealt_to_champions"] = participant.get("totalDamageDealtToChampions")
        row["total_damage_taken"] = participant.get("totalDamageTaken")
        row["damage_dealt_to_objectives"] = participant.get("damageDealtToObjectives")
        row["damage_dealt_to_turrets"] = participant.get("damageDealtToTurrets")
        row["total_heal"] = participant.get("totalHeal")
        row["total_heals_on_teammates"] = participant.get("totalHealsOnTeammates")
        row["total_damage_shielded_on_teammates"] = participant.get("totalDamageShieldedOnTeammates")
        row["vision_score"] = participant.get("visionScore")
        row["wards_placed"] = participant.get("wardsPlaced")
        row["wards_killed"] = participant.get("wardsKilled")
        row["vision_wards_bought"] = participant.get("visionWardsBoughtInGame")
        row["total_minions_killed"] = total_minions
        row["neutral_minions_killed"] = neutral_minions
        row["cs"] = (
            (total_minions or 0)
            + (neutral_minions or 0)
            if (total_minions is not None or neutral_minions is not None)
            else None
        )
        row["double_kills"] = participant.get("doubleKills")
        row["triple_kills"] = participant.get("tripleKills")
        row["quadra_kills"] = participant.get("quadraKills")
        row["penta_kills"] = participant.get("pentaKills")
        row["summoner1_id"] = participant.get("summoner1Id")
        row["summoner2_id"] = participant.get("summoner2Id")
        for slot in range(7):
            row[f"item{slot}"] = participant.get(f"item{slot}")
        row["time_played"] = participant.get("timePlayed")
        row["time_ccing_others"] = participant.get("timeCCingOthers")
        row["total_time_cc_dealt"] = participant.get("totalTimeCCDealt")
        rows.append(row)
    return rows, puuids

# %%
seeds = read_seeds(str(CONFIG["seeds_path"]))
if not seeds:
    raise RuntimeError(f"No seeds found at {CONFIG['seeds_path']}. Populate the file with Riot IDs (Name#Tag) or PUUIDs.")

resolved_seeds: List[Tuple[str, str]] = []
for seed in seeds:
    resolution = resolve_seed(seed)
    if resolution:
        resolved_seeds.append(resolution)

if not resolved_seeds:
    raise RuntimeError("None of the seeds resolved to a PUUID. Verify the entries and API key.")

len(resolved_seeds), resolved_seeds[:5]
# Out:
# [16:11:05] Could not resolve seed 'DNF Quantum#KR1'. Use Riot ID (Name#Tag) or a PUUID.
# [16:11:33] Could not resolve seed 'NASA#쟁구'. Use Riot ID (Name#Tag) or a PUUID.
# [16:12:48] Could not resolve seed '나만 없어 개냥이#냥멍'. Use Riot ID (Name#Tag) or a PUUID.
# [16:13:15] Could not resolve seed 'min#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:13:47] Could not resolve seed '아이스크림 콘 뿔보#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:14:02] Could not resolve seed '아름다운 나라#KT'. Use Riot ID (Name#Tag) or a PUUID.
# [16:14:34] Could not resolve seed '소프트#KT'. Use Riot ID (Name#Tag) or a PUUID.
# [16:14:40] Could not resolve seed 'DK Despair#안산'. Use Riot ID (Name#Tag) or a PUUID.
# [16:15:30] Could not resolve seed 'NoRoo#T1'. Use Riot ID (Name#Tag) or a PUUID.
# [16:15:36] Could not resolve seed '렝 화#RH'. Use Riot ID (Name#Tag) or a PUUID.
# [16:15:45] Could not resolve seed '해 태#T1'. Use Riot ID (Name#Tag) or a PUUID.
# [16:15:54] Could not resolve seed '깜지곰#링곰'. Use Riot ID (Name#Tag) or a PUUID.
# [16:15:57] Could not resolve seed '김잡초#KR'. Use Riot ID (Name#Tag) or a PUUID.
# [16:15:58] Could not resolve seed '마 리#골드'. Use Riot ID (Name#Tag) or a PUUID.
# [16:16:05] Could not resolve seed '타코피#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:16:23] Could not resolve seed 'Kingcrimson#知鸟'. Use Riot ID (Name#Tag) or a PUUID.
# [16:16:25] Could not resolve seed '황혼우주자야#황혼'. Use Riot ID (Name#Tag) or a PUUID.
# [16:16:44] Could not resolve seed '쭈쭈바#뽕따'. Use Riot ID (Name#Tag) or a PUUID.
# [16:16:53] Could not resolve seed 'dhx#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:17:36] Could not resolve seed '도레미파솔미레도#계이름'. Use Riot ID (Name#Tag) or a PUUID.
# [16:17:46] Could not resolve seed '무 희#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:18:04] Could not resolve seed '렝 화#렝화'. Use Riot ID (Name#Tag) or a PUUID.
# [16:18:22] Could not resolve seed 'laura#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:18:34] Could not resolve seed 'won#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:19:50] Could not resolve seed '럭 스#1등'. Use Riot ID (Name#Tag) or a PUUID.
# [16:19:52] Could not resolve seed '내가지은성#곧무너짐'. Use Riot ID (Name#Tag) or a PUUID.
# [16:20:21] Could not resolve seed '탄붕어빵#st'. Use Riot ID (Name#Tag) or a PUUID.
# [16:20:49] Could not resolve seed '펠 레#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:21:12] Could not resolve seed '여름시러#ST'. Use Riot ID (Name#Tag) or a PUUID.
# [16:21:20] Could not resolve seed '칼날보리#보리'. Use Riot ID (Name#Tag) or a PUUID.
# (469,
#  [('N3t4YEyVIKhXM8TeWQXcsc7LuFW8DrrxLwBDkwUqYlBfFZ8tTiubJeZljFt_RqVCslJLPvFFkYXhlA',
#    'DRX kyeahoo#0813'),
#   ('cFWxSdXdtUfU6_tbByX0HAY-x4v0EzI0Bp9C7iZmvqwWEk4i2zRbBxx-XzzmTxNr3hXgHAYYWzFx2A',
#    '진돗개#0415'),
#   ('KQJxaCtJ9GOA-_2IWrkXabJhSsO8dqhiKkT3ZaBSRR9gPx_718IwWe1UeJ4BTPq8TJ5yO9frMas7dA',
#    'Peyz#KR11'),
#   ('cpwv88LWJbzd0poxei5Uj2EkvHZJNkU9ldroWdtMYqYFLgruoqQgXfFz-H1wh42YNqc2YgABysaZ9g',
#    'Vincenzo#kr40'),
#   ('NOu1vi3U3LJdz_vLRCHumr6GGqGJIMo7x6O1ECDd1OgfreTbw1LaV9x0f-iaVFfg-tSZwqRWWUTdQw',
#    'Hype#KRR')])

# %%
def collect_matches(
    target_match_count: int,
    seeds: Sequence[Tuple[str, str]],
    output_csv: Path,
    max_player_queue: int,
    progress_every: int = 50,
) -> List[str]:
    """Harvest ranked matches and write per-participant rows to CSV.

    Returns the list of unique match_ids encountered."""
    output_csv.parent.mkdir(parents=True, exist_ok=True)
    queue: deque[str] = deque()
    cursor: Dict[str, int] = {}
    known_puuids: set[str] = set()
    for puuid, _ in seeds:
        queue.append(puuid)
        cursor[puuid] = 0
        known_puuids.add(puuid)

    seen_matches: set[str] = set()
    total_rows = 0
    matches_collected = 0
    start_time = time.time()

    with output_csv.open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=FIELDNAMES, extrasaction="ignore")
        writer.writeheader()
        while queue and matches_collected < target_match_count:
            puuid = queue.popleft()
            start = cursor.get(puuid, 0)
            match_ids = fetch_match_ids(puuid, start)
            if not match_ids:
                continue
            cursor[puuid] = start + len(match_ids)
            queue.append(puuid)

            for match_id in match_ids:
                if match_id in seen_matches:
                    continue

                match_data = fetch_match(match_id)
                seen_matches.add(match_id)
                if not match_data:
                    continue

                rows, puuids = extract_rows(match_data)
                if not rows:
                    continue

                writer.writerows(rows)
                handle.flush()
                total_rows += len(rows)
                matches_collected += 1

                for new_puuid in puuids:
                    if (
                        new_puuid
                        and new_puuid not in known_puuids
                        and len(known_puuids) < max_player_queue
                    ):
                        known_puuids.add(new_puuid)
                        cursor[new_puuid] = 0
                        queue.append(new_puuid)

                if matches_collected % progress_every == 0:
                    elapsed = time.time() - start_time
                    print(
                        f"Collected {matches_collected} matches ({total_rows} rows) in {elapsed/60:.1f} minutes."
                    )

                if matches_collected >= target_match_count:
                    break

                if SLEEP_BETWEEN_MATCHES > 0:
                    time.sleep(SLEEP_BETWEEN_MATCHES)

    print(
        f"Finished match harvest: {matches_collected} unique matches written to {output_csv}."
    )
    return sorted(seen_matches)

# %%
unique_match_ids = collect_matches(
    target_match_count=CONFIG["target_match_count"],
    seeds=resolved_seeds,
    output_csv=CONFIG["raw_output_path"],
    max_player_queue=CONFIG["max_player_queue"],
)
len(unique_match_ids)
# Out:
# Collected 50 matches (500 rows) in 1.2 minutes.
# Collected 100 matches (1000 rows) in 2.5 minutes.
# Collected 150 matches (1500 rows) in 3.8 minutes.
# Collected 200 matches (2000 rows) in 5.1 minutes.
# Collected 250 matches (2500 rows) in 6.4 minutes.
# Collected 300 matches (3000 rows) in 7.8 minutes.
# Collected 350 matches (3500 rows) in 9.1 minutes.
# Collected 400 matches (4000 rows) in 10.5 minutes.
# Collected 450 matches (4500 rows) in 11.7 minutes.
# Collected 500 matches (5000 rows) in 12.9 minutes.
# Collected 550 matches (5500 rows) in 14.1 minutes.
# Collected 600 matches (6000 rows) in 15.4 minutes.
# Collected 650 matches (6500 rows) in 16.8 minutes.
# Collected 700 matches (7000 rows) in 18.0 minutes.
# Collected 750 matches (7500 rows) in 19.3 minutes.
# Collected 800 matches (8000 rows) in 20.6 minutes.
# Collected 850 matches (8500 rows) in 22.0 minutes.
# Collected 900 matches (9000 rows) in 23.3 minutes.
# Collected 950 matches (9500 rows) in 24.6 minutes.
# Collected 1000 matches (10000 rows) in 25.9 minutes.
# Collected 1050 matches (10500 rows) in 27.2 minutes.
# Collected 1100 matches (11000 rows) in 28.5 minutes.
# Collected 1150 matches (11500 rows) in 29.9 minutes.
# [16:52:13] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820357668 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:52:31] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820357668 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:52:50] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820357668 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:53:10] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820357668 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:53:30] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820357668 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:53:35] Gave up on https://asia.api.riotgames.com/lol/match/v5/matches/KR_7820357668 after 5 attempts.
# [16:53:52] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820318565 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:54:10] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820318565 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:54:29] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820318565 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:54:49] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7820318565 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:56:05] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792748929 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:56:22] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792748929 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:56:43] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792656221 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:57:01] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792656221 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:57:19] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792656221 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:57:39] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792656221 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:58:00] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792656221 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:58:05] Gave up on https://asia.api.riotgames.com/lol/match/v5/matches/KR_7792656221 after 5 attempts.
# [16:58:22] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792241823 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [16:58:39] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7792241823 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# Collected 1200 matches (12000 rows) in 37.2 minutes.
# Collected 1250 matches (12500 rows) in 38.5 minutes.
# Collected 1300 matches (13000 rows) in 39.8 minutes.
# Collected 1350 matches (13500 rows) in 41.2 minutes.
# Collected 1400 matches (14000 rows) in 42.5 minutes.
# Collected 1450 matches (14500 rows) in 43.8 minutes.
# Collected 1500 matches (15000 rows) in 45.1 minutes.
# Collected 1550 matches (15500 rows) in 46.4 minutes.
# Collected 1600 matches (16000 rows) in 47.7 minutes.
# Collected 1650 matches (16500 rows) in 49.1 minutes.
# Collected 1700 matches (17000 rows) in 50.4 minutes.
# Collected 1750 matches (17500 rows) in 51.7 minutes.
# Collected 1800 matches (18000 rows) in 53.0 minutes.
# Collected 1850 matches (18500 rows) in 54.3 minutes.
# Collected 1900 matches (19000 rows) in 55.6 minutes.
# Collected 1950 matches (19500 rows) in 56.9 minutes.
# Collected 2000 matches (20000 rows) in 58.3 minutes.
# Collected 2050 matches (20500 rows) in 59.6 minutes.
# Collected 2100 matches (21000 rows) in 60.9 minutes.
# Collected 2150 matches (21500 rows) in 62.2 minutes.
# Collected 2200 matches (22000 rows) in 63.6 minutes.
# Collected 2250 matches (22500 rows) in 64.9 minutes.
# Collected 2300 matches (23000 rows) in 66.2 minutes.
# Collected 2350 matches (23500 rows) in 67.6 minutes.
# Collected 2400 matches (24000 rows) in 68.9 minutes.
# Collected 2450 matches (24500 rows) in 70.2 minutes.
# Collected 2500 matches (25000 rows) in 71.5 minutes.
# Collected 2550 matches (25500 rows) in 72.9 minutes.
# Collected 2600 matches (26000 rows) in 74.1 minutes.
# Collected 2650 matches (26500 rows) in 75.4 minutes.
# Collected 2700 matches (27000 rows) in 76.6 minutes.
# Collected 2750 matches (27500 rows) in 77.8 minutes.
# Collected 2800 matches (28000 rows) in 79.2 minutes.
# Collected 2850 matches (28500 rows) in 80.5 minutes.
# Collected 2900 matches (29000 rows) in 82.2 minutes.
# Collected 2950 matches (29500 rows) in 84.0 minutes.
# Collected 3000 matches (30000 rows) in 85.6 minutes.
# Collected 3050 matches (30500 rows) in 87.0 minutes.
# Collected 3100 matches (31000 rows) in 88.6 minutes.
# Collected 3150 matches (31500 rows) in 90.4 minutes.
# Collected 3200 matches (32000 rows) in 91.9 minutes.
# Collected 3250 matches (32500 rows) in 93.3 minutes.
# Collected 3300 matches (33000 rows) in 94.7 minutes.
# Collected 3350 matches (33500 rows) in 96.1 minutes.
# Collected 3400 matches (34000 rows) in 97.5 minutes.
# Collected 3450 matches (34500 rows) in 98.9 minutes.
# Collected 3500 matches (35000 rows) in 100.4 minutes.
# Collected 3550 matches (35500 rows) in 101.9 minutes.
# Collected 3600 matches (36000 rows) in 103.3 minutes.
# Collected 3650 matches (36500 rows) in 104.7 minutes.
# Collected 3700 matches (37000 rows) in 106.1 minutes.
# Collected 3750 matches (37500 rows) in 107.5 minutes.
# Collected 3800 matches (38000 rows) in 108.9 minutes.
# Collected 3850 matches (38500 rows) in 110.2 minutes.
# Collected 3900 matches (39000 rows) in 111.6 minutes.
# Collected 3950 matches (39500 rows) in 113.0 minutes.
# Collected 4000 matches (40000 rows) in 114.3 minutes.
# Collected 4050 matches (40500 rows) in 115.7 minutes.
# Collected 4100 matches (41000 rows) in 117.1 minutes.
# Collected 4150 matches (41500 rows) in 118.4 minutes.
# Collected 4200 matches (42000 rows) in 119.8 minutes.
# Collected 4250 matches (42500 rows) in 121.1 minutes.
# Collected 4300 matches (43000 rows) in 122.4 minutes.
# Collected 4350 matches (43500 rows) in 123.8 minutes.
# Collected 4400 matches (44000 rows) in 125.2 minutes.
# Collected 4450 matches (44500 rows) in 126.8 minutes.
# Collected 4500 matches (45000 rows) in 128.2 minutes.
# Collected 4550 matches (45500 rows) in 129.7 minutes.
# Collected 4600 matches (46000 rows) in 131.1 minutes.
# Collected 4650 matches (46500 rows) in 132.4 minutes.
# Collected 4700 matches (47000 rows) in 133.6 minutes.
# Collected 4750 matches (47500 rows) in 134.8 minutes.
# Collected 4800 matches (48000 rows) in 136.1 minutes.
# Collected 4850 matches (48500 rows) in 137.4 minutes.
# Collected 4900 matches (49000 rows) in 138.7 minutes.
# Collected 4950 matches (49500 rows) in 140.0 minutes.
# Collected 5000 matches (50000 rows) in 141.4 minutes.
# Collected 5050 matches (50500 rows) in 142.7 minutes.
# Collected 5100 matches (51000 rows) in 144.0 minutes.
# Collected 5150 matches (51500 rows) in 145.3 minutes.
# Collected 5200 matches (52000 rows) in 146.7 minutes.
# Collected 5250 matches (52500 rows) in 148.0 minutes.
# Collected 5300 matches (53000 rows) in 149.3 minutes.
# Collected 5350 matches (53500 rows) in 150.6 minutes.
# Collected 5400 matches (54000 rows) in 151.9 minutes.
# Collected 5450 matches (54500 rows) in 153.4 minutes.
# Collected 5500 matches (55000 rows) in 154.7 minutes.
# Collected 5550 matches (55500 rows) in 156.0 minutes.
# Collected 5600 matches (56000 rows) in 157.3 minutes.
# Collected 5650 matches (56500 rows) in 158.6 minutes.
# Collected 5700 matches (57000 rows) in 159.9 minutes.
# Collected 5750 matches (57500 rows) in 161.3 minutes.
# Collected 5800 matches (58000 rows) in 162.6 minutes.
# Collected 5850 matches (58500 rows) in 163.8 minutes.
# Collected 5900 matches (59000 rows) in 165.1 minutes.
# Collected 5950 matches (59500 rows) in 166.4 minutes.
# Collected 6000 matches (60000 rows) in 167.7 minutes.
# Collected 6050 matches (60500 rows) in 169.0 minutes.
# Collected 6100 matches (61000 rows) in 170.3 minutes.
# Collected 6150 matches (61500 rows) in 171.6 minutes.
# Collected 6200 matches (62000 rows) in 172.9 minutes.
# Collected 6250 matches (62500 rows) in 174.1 minutes.
# Collected 6300 matches (63000 rows) in 175.3 minutes.
# Collected 6350 matches (63500 rows) in 176.5 minutes.
# Collected 6400 matches (64000 rows) in 177.7 minutes.
# Collected 6450 matches (64500 rows) in 179.0 minutes.
# Collected 6500 matches (65000 rows) in 180.3 minutes.
# Collected 6550 matches (65500 rows) in 181.6 minutes.
# Collected 6600 matches (66000 rows) in 182.9 minutes.
# Collected 6650 matches (66500 rows) in 184.2 minutes.
# Collected 6700 matches (67000 rows) in 185.5 minutes.
# Collected 6750 matches (67500 rows) in 187.0 minutes.
# Collected 6800 matches (68000 rows) in 188.9 minutes.
# Collected 6850 matches (68500 rows) in 190.2 minutes.
# Collected 6900 matches (69000 rows) in 191.5 minutes.
# Collected 6950 matches (69500 rows) in 192.9 minutes.
# Collected 7000 matches (70000 rows) in 194.2 minutes.
# Collected 7050 matches (70500 rows) in 195.5 minutes.
# Collected 7100 matches (71000 rows) in 196.8 minutes.
# Collected 7150 matches (71500 rows) in 198.2 minutes.
# Collected 7200 matches (72000 rows) in 199.4 minutes.
# Collected 7250 matches (72500 rows) in 200.8 minutes.
# Collected 7300 matches (73000 rows) in 202.1 minutes.
# Collected 7350 matches (73500 rows) in 203.5 minutes.
# Collected 7400 matches (74000 rows) in 205.0 minutes.
# Collected 7450 matches (74500 rows) in 206.6 minutes.
# Collected 7500 matches (75000 rows) in 208.2 minutes.
# Collected 7550 matches (75500 rows) in 209.8 minutes.
# Collected 7600 matches (76000 rows) in 211.3 minutes.
# Collected 7650 matches (76500 rows) in 213.3 minutes.
# Collected 7700 matches (77000 rows) in 215.4 minutes.
# Collected 7750 matches (77500 rows) in 217.0 minutes.
# Collected 7800 matches (78000 rows) in 218.8 minutes.
# Collected 7850 matches (78500 rows) in 220.9 minutes.
# Collected 7900 matches (79000 rows) in 222.9 minutes.
# Collected 7950 matches (79500 rows) in 224.9 minutes.
# Collected 8000 matches (80000 rows) in 227.0 minutes.
# [20:09:53] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out. (read timeout=20)). Retrying...
# Collected 8050 matches (80500 rows) in 229.3 minutes.
# Collected 8100 matches (81000 rows) in 231.3 minutes.
# Collected 8150 matches (81500 rows) in 233.1 minutes.
# Collected 8200 matches (82000 rows) in 235.0 minutes.
# Collected 8250 matches (82500 rows) in 236.6 minutes.
# Collected 8300 matches (83000 rows) in 238.2 minutes.
# Collected 8350 matches (83500 rows) in 240.0 minutes.
# Collected 8400 matches (84000 rows) in 241.7 minutes.
# Collected 8450 matches (84500 rows) in 243.3 minutes.
# [20:26:16] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out. (read timeout=20)). Retrying...
# [20:27:21] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out. (read timeout=20)). Retrying...
# Collected 8500 matches (85000 rows) in 246.0 minutes.
# Collected 8550 matches (85500 rows) in 248.0 minutes.
# [20:30:55] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out.). Retrying...
# [20:31:48] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out.). Retrying...
# [20:32:26] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out. (read timeout=20)). Retrying...
# Collected 8600 matches (86000 rows) in 251.5 minutes.
# Collected 8650 matches (86500 rows) in 254.0 minutes.
# Collected 8700 matches (87000 rows) in 255.7 minutes.
# [20:38:17] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Read timed out. (read timeout=20)). Retrying...
# Collected 8750 matches (87500 rows) in 258.4 minutes.
# Collected 8800 matches (88000 rows) in 259.9 minutes.
# Collected 8850 matches (88500 rows) in 261.6 minutes.
# Collected 8900 matches (89000 rows) in 263.1 minutes.
# Collected 8950 matches (89500 rows) in 264.7 minutes.
# Collected 9000 matches (90000 rows) in 266.2 minutes.
# Collected 9050 matches (90500 rows) in 267.7 minutes.
# Collected 9100 matches (91000 rows) in 269.0 minutes.
# Collected 9150 matches (91500 rows) in 270.5 minutes.
# Collected 9200 matches (92000 rows) in 271.8 minutes.
# Collected 9250 matches (92500 rows) in 273.2 minutes.
# Collected 9300 matches (93000 rows) in 274.6 minutes.
# Collected 9350 matches (93500 rows) in 275.9 minutes.
# Collected 9400 matches (94000 rows) in 277.2 minutes.
# Collected 9450 matches (94500 rows) in 278.6 minutes.
# Collected 9500 matches (95000 rows) in 279.9 minutes.
# Collected 9550 matches (95500 rows) in 281.3 minutes.
# Collected 9600 matches (96000 rows) in 282.6 minutes.
# Collected 9650 matches (96500 rows) in 284.0 minutes.
# Collected 9700 matches (97000 rows) in 285.3 minutes.
# Collected 9750 matches (97500 rows) in 286.7 minutes.
# Collected 9800 matches (98000 rows) in 288.0 minutes.
# Collected 9850 matches (98500 rows) in 289.4 minutes.
# Collected 9900 matches (99000 rows) in 290.8 minutes.
# Collected 9950 matches (99500 rows) in 292.1 minutes.
# Collected 10000 matches (100000 rows) in 293.5 minutes.
# Finished match harvest: 10000 unique matches written to raw.csv.
# 10002

# %%
match_ids_series = pd.read_csv(CONFIG["raw_output_path"], usecols=["match_id"]).squeeze("columns")
unique_match_ids = match_ids_series.dropna().drop_duplicates().tolist()
print(f"{len(unique_match_ids)} unique matches available for timeline download.")
# Out:
# 10000 unique matches available for timeline download.

# %%
def fetch_and_store_timelines(match_ids: Sequence[str], config: dict) -> None:
    timeline_dir = Path(config["timeline_dir"])
    timeline_dir.mkdir(parents=True, exist_ok=True)

    saved = 0
    skipped = 0
    total = len(match_ids)

    for idx, match_id in enumerate(match_ids, start=1):
        output_path = timeline_dir / f"{match_id}.json"
        if output_path.exists():
            skipped += 1
            continue

        url = f"https://{config['region_routing']}.api.riotgames.com/lol/match/v5/matches/{match_id}/timeline"
        payload = riot_get(url)
        if not isinstance(payload, dict):
            print(f"Timeline unavailable for {match_id} (response type {type(payload)}).")
            continue

        with output_path.open("w", encoding="utf-8") as handle:
            json.dump(payload, handle)
        saved += 1

        if idx % 100 == 0 or idx == total:
            print(
                f"Processed {idx}/{total} timelines | saved={saved} skipped={skipped}."
            )

    print(f"Timeline download complete: {saved} new files, {skipped} skipped.")

# %%
fetch_and_store_timelines(unique_match_ids, CONFIG)
# Out:
# Processed 100/10000 timelines | saved=100 skipped=0.
# Processed 200/10000 timelines | saved=200 skipped=0.
# Processed 300/10000 timelines | saved=300 skipped=0.
# Processed 400/10000 timelines | saved=400 skipped=0.
# Processed 500/10000 timelines | saved=500 skipped=0.
# Processed 600/10000 timelines | saved=600 skipped=0.
# Processed 700/10000 timelines | saved=700 skipped=0.
# Processed 800/10000 timelines | saved=800 skipped=0.
# Processed 900/10000 timelines | saved=900 skipped=0.
# Processed 1000/10000 timelines | saved=1000 skipped=0.
# Processed 1100/10000 timelines | saved=1100 skipped=0.
# Processed 1200/10000 timelines | saved=1200 skipped=0.
# Processed 1300/10000 timelines | saved=1300 skipped=0.
# Processed 1400/10000 timelines | saved=1400 skipped=0.
# Processed 1500/10000 timelines | saved=1500 skipped=0.
# Processed 1600/10000 timelines | saved=1600 skipped=0.
# Processed 1700/10000 timelines | saved=1700 skipped=0.
# Processed 1800/10000 timelines | saved=1800 skipped=0.
# Processed 1900/10000 timelines | saved=1900 skipped=0.
# Processed 2000/10000 timelines | saved=2000 skipped=0.
# Processed 2100/10000 timelines | saved=2100 skipped=0.
# Processed 2200/10000 timelines | saved=2200 skipped=0.
# [08:50:37] Request error (Response ended prematurely). Retrying...
# Processed 2300/10000 timelines | saved=2300 skipped=0.
# Processed 2400/10000 timelines | saved=2400 skipped=0.
# Processed 2500/10000 timelines | saved=2500 skipped=0.
# Processed 2600/10000 timelines | saved=2600 skipped=0.
# Processed 2700/10000 timelines | saved=2700 skipped=0.
# Processed 2800/10000 timelines | saved=2800 skipped=0.
# Processed 2900/10000 timelines | saved=2900 skipped=0.
# Processed 3000/10000 timelines | saved=3000 skipped=0.
# Processed 3100/10000 timelines | saved=3100 skipped=0.
# Processed 3200/10000 timelines | saved=3200 skipped=0.
# Processed 3300/10000 timelines | saved=3300 skipped=0.
# Processed 3400/10000 timelines | saved=3400 skipped=0.
# Processed 3500/10000 timelines | saved=3500 skipped=0.
# Processed 3600/10000 timelines | saved=3600 skipped=0.
# Processed 3700/10000 timelines | saved=3700 skipped=0.
# Processed 3800/10000 timelines | saved=3800 skipped=0.
# Processed 3900/10000 timelines | saved=3900 skipped=0.
# Processed 4000/10000 timelines | saved=4000 skipped=0.
# Processed 4100/10000 timelines | saved=4100 skipped=0.
# Processed 4200/10000 timelines | saved=4200 skipped=0.
# Processed 4300/10000 timelines | saved=4300 skipped=0.
# Processed 4400/10000 timelines | saved=4400 skipped=0.
# Processed 4500/10000 timelines | saved=4500 skipped=0.
# Processed 4600/10000 timelines | saved=4600 skipped=0.
# Processed 4700/10000 timelines | saved=4700 skipped=0.
# Processed 4800/10000 timelines | saved=4800 skipped=0.
# Processed 4900/10000 timelines | saved=4900 skipped=0.
# Processed 5000/10000 timelines | saved=5000 skipped=0.
# Processed 5100/10000 timelines | saved=5100 skipped=0.
# Processed 5200/10000 timelines | saved=5200 skipped=0.
# Processed 5300/10000 timelines | saved=5300 skipped=0.
# Processed 5400/10000 timelines | saved=5400 skipped=0.
# Processed 5500/10000 timelines | saved=5500 skipped=0.
# Processed 5600/10000 timelines | saved=5600 skipped=0.
# Processed 5700/10000 timelines | saved=5700 skipped=0.
# Processed 5800/10000 timelines | saved=5800 skipped=0.
# Processed 5900/10000 timelines | saved=5900 skipped=0.
# Processed 6000/10000 timelines | saved=6000 skipped=0.
# Processed 6100/10000 timelines | saved=6100 skipped=0.
# Processed 6200/10000 timelines | saved=6200 skipped=0.
# Processed 6300/10000 timelines | saved=6300 skipped=0.
# Processed 6400/10000 timelines | saved=6400 skipped=0.
# Processed 6500/10000 timelines | saved=6500 skipped=0.
# Processed 6600/10000 timelines | saved=6600 skipped=0.
# Processed 6700/10000 timelines | saved=6700 skipped=0.
# Processed 6800/10000 timelines | saved=6800 skipped=0.
# Processed 6900/10000 timelines | saved=6900 skipped=0.
# Processed 7000/10000 timelines | saved=7000 skipped=0.
# Processed 7100/10000 timelines | saved=7100 skipped=0.
# Processed 7200/10000 timelines | saved=7200 skipped=0.
# Processed 7300/10000 timelines | saved=7300 skipped=0.
# Processed 7400/10000 timelines | saved=7400 skipped=0.
# Processed 7500/10000 timelines | saved=7500 skipped=0.
# Processed 7600/10000 timelines | saved=7600 skipped=0.
# Processed 7700/10000 timelines | saved=7700 skipped=0.
# Processed 7800/10000 timelines | saved=7800 skipped=0.
# Processed 7900/10000 timelines | saved=7900 skipped=0.
# Processed 8000/10000 timelines | saved=8000 skipped=0.
# Processed 8100/10000 timelines | saved=8100 skipped=0.
# Processed 8200/10000 timelines | saved=8200 skipped=0.
# Processed 8300/10000 timelines | saved=8300 skipped=0.
# Processed 8400/10000 timelines | saved=8400 skipped=0.
# Processed 8500/10000 timelines | saved=8500 skipped=0.
# Processed 8600/10000 timelines | saved=8600 skipped=0.
# Processed 8700/10000 timelines | saved=8700 skipped=0.
# Processed 8800/10000 timelines | saved=8800 skipped=0.
# Processed 8900/10000 timelines | saved=8900 skipped=0.
# Processed 9000/10000 timelines | saved=9000 skipped=0.
# Processed 9100/10000 timelines | saved=9100 skipped=0.
# Processed 9200/10000 timelines | saved=9200 skipped=0.
# [12:39:55] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7755824660/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:40:13] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7755824660/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:40:32] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7755824660/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:40:52] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7755824660/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:41:13] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7755824660/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:41:18] Gave up on https://asia.api.riotgames.com/lol/match/v5/matches/KR_7755824660/timeline after 5 attempts.
# Timeline unavailable for KR_7755824660 (response type <class 'NoneType'>).
# [12:41:34] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748340800/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:41:52] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748340800/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:42:11] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748340800/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:42:31] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748340800/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:42:57] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748276412/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:43:15] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748276412/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:43:34] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748276412/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:43:54] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748276412/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:44:15] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7748276412/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:44:20] Gave up on https://asia.api.riotgames.com/lol/match/v5/matches/KR_7748276412/timeline after 5 attempts.
# Timeline unavailable for KR_7748276412 (response type <class 'NoneType'>).
# [12:44:36] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7746225807/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:44:54] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7746225807/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:45:13] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7746225807/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# [12:45:33] Request error (HTTPSConnectionPool(host='asia.api.riotgames.com', port=443): Max retries exceeded with url: /lol/match/v5/matches/KR_7746225807/timeline (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))). Retrying...
# Processed 9300/10000 timelines | saved=9298 skipped=0.
# Processed 9400/10000 timelines | saved=9398 skipped=0.
# Processed 9500/10000 timelines | saved=9498 skipped=0.
# Processed 9600/10000 timelines | saved=9598 skipped=0.
# Processed 9700/10000 timelines | saved=9698 skipped=0.
# Processed 9800/10000 timelines | saved=9798 skipped=0.
# Processed 9900/10000 timelines | saved=9898 skipped=0.
# Processed 10000/10000 timelines | saved=9998 skipped=0.
# Timeline download complete: 9998 new files, 0 skipped.
