# %%
#get the top1000 ranked players in KR region.
import requests
from bs4 import BeautifulSoup

url = "https://op.gg/lol/leaderboards/tier?region=kr&page=5"

response = requests.get(url)
html_content = response.text

soup = BeautifulSoup(html_content, 'html.parser')

table = soup.find('tbody')

players = table.find_all('tr')
player_ids = []

for player in players:
    player_id = player.get('id')
    if player_id:
        player_id = player_id.replace('-', '#')
        player_ids.append(player_id)

for pid in player_ids:
    print(pid)
    
#with open('player_ids.txt', 'w') as file:
#    for pid in player_ids:
#        file.write(pid + '\n')
# Out:
# 꼬마딩구리#KR1
# 화내지말자#0722
# 주 성#KR06
# 로키의 코 드리블#2004
# 아름다워지고싶요#KR1
# 꿀잼사과잼#KR1
# Soft#KR1
# 한태울#KR01
# 1234412351#444
# 홍 시#말티푸
# 충 치#충치1
# JZADfans#KR1
# 권선원#KR1
# 수원 남현준#1111
# 리즈윈#332
# 愛情不太顺#iu99
# LaLaLove#KR2
# 陪小寒岁岁年年#gyh
# T1 Cypher#KR21
# 큐 지#KR1
# Okay cool#KR1
# 오 너#111
# gaubeo202#KR1
# 인천물주먹#인천사람
# 럭 스#1 등
# 내가지은성#곧 무너짐
# xxxxxm#KR1
# 하얗고예쁨#KR1
# 바켱낙#KR1
# 김도현#토근이
# 그냥 즐겨#zzz
# 천안오대륙통닭#생맥주
# 기억상실증#KR2
# 모든일은같이#KR1
# 듀 시#KR1
# sad and bad#KR1
# QiFeng34D#小奶熊
# Weapon#kr2
# 크리스티아누 호날두#GOAT0
# 바바바밤#1999
# 게이온#KR1
# 1997#KR1
# 시 루#cat
# 짱 구#Zero
# Serendipity#KR06
# 전민혁#KR1
# 엑스큐트#LOL
# 탄붕어빵#s t
# Savage#KR1
# dream about you#4get
# JUGKlNG#테무캐니언
# 이망구#KR33
# 허수아비#무적이야
# LDMulti#KR1
# Signal z#KR1
# usus#0313
# No Cost#마리골드
# 카르맛#KR1
# 조관우급 늪 설치#KR1
# Xun#OOK
# Robin#星期日
# 전상득#0805
# Hebi#스케치
# 행복이론#494
# 파르와루도#KR11
# 김채원 맞짱 뜰래#미안해
# lion god#12345
# 日益澄明#TES
# 그땐 그저 좋았다#KR1
# Sama#KR2
# 펠 레#S T
# Chama#kr2
# 깽깽이#kr3
# Chamomile#KR214
# bei#0606
# 동산재기#again
# Nuouououo#KR1
# 온 재#KR1
# yang#8687
# LIVE#CTYL
# 깜찍이#321
# aierlanxiaozhu#01321
# 매화수#하이트
# 1700 games#KR55
# 꿈이있으니질수가없다#Keple
# 태 윤#KDF
# 그브충이#KR1
# 달 카#1997
# 여름시러#S T
# TheHank#反迷你
# 抖音丶幻影洛#41111
# 비밀공작원#KR1
# 조광희#0111
# 草将雨辰#fyy
# 칼날보리#보 리
# what is freedom#dyx
# FA DECADE#ZHX
# 抖音 阿撸撸#360
# ST 스트라이커#음바페

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\asusrog\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\asusROG\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
